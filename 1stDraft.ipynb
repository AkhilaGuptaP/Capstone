# %% [markdown]
# <a href="https://colab.research.google.com/github/AkhilaGuptaP/Capstone/blob/main/1stDraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets_2/Airbnb NYC 2019.csv')
df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# reviews_per_month                                             0.21
# calculated_host_listings_count                                   6
# availability_365                                               365
#
#                                                     1  \
# id                                               2595
# name                            Skylit Midtown Castle
# host_id                                          2845
# host_name                                    Jennifer
# neighbourhood_group                         Manhattan
# neighbourhood                                 Midtown
# latitude                                     40.75362
# longitude                                   -73.98377
# room_type                             Entire home/apt
# price                                             225
# minimum_nights                                      1
# number_of_reviews                                  45
# last_review                                2019-05-21
# reviews_per_month                                0.38
# calculated_host_listings_count                      2
# availability_365                                  355
#
#                                                                   2  \
# id                                                             3647
# name                            THE VILLAGE OF HARLEM....NEW YORK !
# host_id                                                        4632
# host_name                                                 Elisabeth
# neighbourhood_group                                       Manhattan
# neighbourhood                                                Harlem
# latitude                                                   40.80902
# longitude                                                  -73.9419
# room_type                                              Private room
# price                                                           150
# minimum_nights                                                    3
# number_of_reviews                                                 0
# last_review                                                     NaN
# reviews_per_month                                               NaN
# calculated_host_listings_count                                    1
# availability_365                                                365
#
#                                                               3  \
# id                                                         3831
# name                            Cozy Entire Floor of Brownstone
# host_id                                                    4869
# host_name                                           LisaRoxanne
# neighbourhood_group                                    Brooklyn
# neighbourhood                                      Clinton Hill
# latitude                                               40.68514
# longitude                                             -73.95976
# room_type                                       Entire home/apt
# price                                                        89
# minimum_nights                                                1
# number_of_reviews                                           270
# last_review                                          2019-07-05
# reviews_per_month                                          4.64
# calculated_host_listings_count                                1
# availability_365                                            194
#
#                                                                                4
# id                                                                          5022
# name                            Entire Apt: Spacious Studio/Loft by central park
# host_id                                                                     7192
# host_name                                                                  Laura
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                        East Harlem
# latitude                                                                40.79851
# longitude                                                              -73.94399
# room_type                                                        Entire home/apt
# price                                                                         80
# minimum_nights                                                                10
# number_of_reviews                                                              9
# last_review                                                           2018-11-19
# reviews_per_month                                                            0.1
# calculated_host_listings_count                                                 1
# availability_365                                                               0

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['calculated_host_listings_count']
# Out:
# 0        6
# 1        2
# 2        1
# 3        1
# 4        1
#         ..
# 48890    2
# 48891    2
# 48892    1
# 48893    6
# 48894    1
# Name: calculated_host_listings_count, Length: 48895, dtype: int64

# %%
df['reviews_per_month'].fillna(0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               48895 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
columns_to_fill = ['last_review','name', 'host_name']

df[columns_to_fill]=df[columns_to_fill].fillna('NA')

# %%
df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0          NA
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2               0.00                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# reviews_per_month                                             0.21
# calculated_host_listings_count                                   6
# availability_365                                               365
#
#                                                     1  \
# id                                               2595
# name                            Skylit Midtown Castle
# host_id                                          2845
# host_name                                    Jennifer
# neighbourhood_group                         Manhattan
# neighbourhood                                 Midtown
# latitude                                     40.75362
# longitude                                   -73.98377
# room_type                             Entire home/apt
# price                                             225
# minimum_nights                                      1
# number_of_reviews                                  45
# last_review                                2019-05-21
# reviews_per_month                                0.38
# calculated_host_listings_count                      2
# availability_365                                  355
#
#                                                                   2  \
# id                                                             3647
# name                            THE VILLAGE OF HARLEM....NEW YORK !
# host_id                                                        4632
# host_name                                                 Elisabeth
# neighbourhood_group                                       Manhattan
# neighbourhood                                                Harlem
# latitude                                                   40.80902
# longitude                                                  -73.9419
# room_type                                              Private room
# price                                                           150
# minimum_nights                                                    3
# number_of_reviews                                                 0
# last_review                                                      NA
# reviews_per_month                                               0.0
# calculated_host_listings_count                                    1
# availability_365                                                365
#
#                                                               3  \
# id                                                         3831
# name                            Cozy Entire Floor of Brownstone
# host_id                                                    4869
# host_name                                           LisaRoxanne
# neighbourhood_group                                    Brooklyn
# neighbourhood                                      Clinton Hill
# latitude                                               40.68514
# longitude                                             -73.95976
# room_type                                       Entire home/apt
# price                                                        89
# minimum_nights                                                1
# number_of_reviews                                           270
# last_review                                          2019-07-05
# reviews_per_month                                          4.64
# calculated_host_listings_count                                1
# availability_365                                            194
#
#                                                                                4
# id                                                                          5022
# name                            Entire Apt: Spacious Studio/Loft by central park
# host_id                                                                     7192
# host_name                                                                  Laura
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                        East Harlem
# latitude                                                                40.79851
# longitude                                                              -73.94399
# room_type                                                        Entire home/apt
# price                                                                         80
# minimum_nights                                                                10
# number_of_reviews                                                              9
# last_review                                                           2018-11-19
# reviews_per_month                                                            0.1
# calculated_host_listings_count                                                 1
# availability_365                                                               0

# %%
#Most popular one as per reviews

sns.barplot(data=df.head(50),y='name',x='number_of_reviews')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='name'>

# %%
reviews_grp=df.groupby('neighbourhood_group')['number_of_reviews'].sum()

reviews_grp
# Out:
# neighbourhood_group
# Bronx             28371
# Brooklyn         486574
# Manhattan        454569
# Queens           156950
# Staten Island     11541
# Name: number_of_reviews, dtype: int64

# %%
reviews_grp=df.groupby('neighbourhood_group')['number_of_reviews'].sum().reset_index()

reviews_grp
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx              28371
# 1            Brooklyn             486574
# 2           Manhattan             454569
# 3              Queens             156950
# 4       Staten Island              11541

# %%
df.head()
room_type_df=df['room_type'].value_counts()
room_type_df
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
sns.set()
plt.pie(room_type_df.values,labels=room_type_df.index,autopct='%1.1f%%') #,palette='muted'
plt.show()

# %%
df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# reviews_per_month                                             0.21
# calculated_host_listings_count                                   6
# availability_365                                               365
# total_reviews                                                 1.89
#
#                                                     1  \
# id                                               2595
# name                            Skylit Midtown Castle
# host_id                                          2845
# host_name                                    Jennifer
# neighbourhood_group                         Manhattan
# neighbourhood                                 Midtown
# latitude                                     40.75362
# longitude                                   -73.98377
# room_type                             Entire home/apt
# price                                             225
# minimum_nights                                      1
# number_of_reviews                                  45
# last_review                                2019-05-21
# reviews_per_month                                0.38
# calculated_host_listings_count                      2
# availability_365                                  355
# total_reviews                                    17.1
#
#                                                                   2  \
# id                                                             3647
# name                            THE VILLAGE OF HARLEM....NEW YORK !
# host_id                                                        4632
# host_name                                                 Elisabeth
# neighbourhood_group                                       Manhattan
# neighbourhood                                                Harlem
# latitude                                                   40.80902
# longitude                                                  -73.9419
# room_type                                              Private room
# price                                                           150
# minimum_nights                                                    3
# number_of_reviews                                                 0
# last_review                                                     NaN
# reviews_per_month                                               0.0
# calculated_host_listings_count                                    1
# availability_365                                                365
# total_reviews                                                   0.0
#
#                                                               3  \
# id                                                         3831
# name                            Cozy Entire Floor of Brownstone
# host_id                                                    4869
# host_name                                           LisaRoxanne
# neighbourhood_group                                    Brooklyn
# neighbourhood                                      Clinton Hill
# latitude                                               40.68514
# longitude                                             -73.95976
# room_type                                       Entire home/apt
# price                                                        89
# minimum_nights                                                1
# number_of_reviews                                           270
# last_review                                          2019-07-05
# reviews_per_month                                          4.64
# calculated_host_listings_count                                1
# availability_365                                            194
# total_reviews                                            1252.8
#
#                                                                                4
# id                                                                          5022
# name                            Entire Apt: Spacious Studio/Loft by central park
# host_id                                                                     7192
# host_name                                                                  Laura
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                        East Harlem
# latitude                                                                40.79851
# longitude                                                              -73.94399
# room_type                                                        Entire home/apt
# price                                                                         80
# minimum_nights                                                                10
# number_of_reviews                                                              9
# last_review                                                           2018-11-19
# reviews_per_month                                                            0.1
# calculated_host_listings_count                                                 1
# availability_365                                                               0
# total_reviews                                                                0.9

# %%
sns.barplot(data=df.head(20),x='name',y='price',hue='room_type',palette='pastel')#
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True,cmap='viridis')
# Out:
# <ipython-input-45-19119b594b53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True,cmap='viridis')
# <Axes: >

# %%
df.sort_values(['neighbourhood','neighbourhood_group'])
# Out:
#              id                                               name    host_id  \
# 510      182177              A PRIVATE FLAT / APARTMENT- $SPECIAL$     873273
# 1167     498120                              Hi Traveler.. welcome    2459648
# 1578     715270  2 Beds/Queen & Full Beautiful Room 40 minsT.Sq...    3684360
# 1666     755528                 PRIVATE BATH/TONS OF SUNLIGHT/SAFE    3684360
# 1706     773041                   Nice beautiful room In the Bronx    3684360
# ...         ...                                                ...        ...
# 47203  35634704  WOODSIDE COMFORTABLE ROOM 15 MINUTES FROM THE ...  266792224
# 47404  35716084               Private rooms And Matchless Location  233050530
# 47712  35876561  Modern house (2 BR Apt) • 30Mins from Time Squ...   76360760
# 48056  36062221                                    SHORT TERM STAY    9037589
# 48431  36265137  Cozy, modern room close to Manhattan for 2 guests  272748063
#
#                host_name neighbourhood_group neighbourhood  latitude  \
# 510    Christian & Carla               Bronx      Allerton  40.86466
# 1167               Ellen               Bronx      Allerton  40.86870
# 1578             Enrique               Bronx      Allerton  40.85956
# 1666             Enrique               Bronx      Allerton  40.85840
# 1706             Enrique               Bronx      Allerton  40.85914
# ...                  ...                 ...           ...       ...
# 47203               Alex              Queens      Woodside  40.74833
# 47404           Suleyman              Queens      Woodside  40.74568
# 47712        Christopher              Queens      Woodside  40.74400
# 48056              Rahib              Queens      Woodside  40.74367
# 48431             Rosana              Queens      Woodside  40.75496
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 510    -73.85709  Entire home/apt    125               2                271
# 1167   -73.85240     Private room     35               7                  2
# 1578   -73.87067     Private room     39               2                169
# 1666   -73.86969  Entire home/apt     49               2                189
# 1706   -73.86979     Private room     38               1                187
# ...          ...              ...    ...             ...                ...
# 47203  -73.90827     Private room     90               2                  1
# 47404  -73.90844     Private room     49               2                  0
# 47712  -73.90185  Entire home/apt    169               1                  0
# 48056  -73.91247     Private room     90               1                  0
# 48431  -73.90685     Private room     50               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 510    2019-06-20               2.84                               2
# 1167   2018-07-23               0.17                               1
# 1578   2019-06-12               2.07                               4
# 1666   2019-06-23               2.32                               4
# 1706   2019-06-23               2.34                               4
# ...           ...                ...                             ...
# 47203  2019-07-01               1.00                               1
# 47404          NA               0.00                               1
# 47712          NA               0.00                               1
# 48056          NA               0.00                               1
# 48431          NA               0.00                               1
#
#        availability_365
# 510                 347
# 1167                 90
# 1578                306
# 1666                238
# 1706                241
# ...                 ...
# 47203               365
# 47404               177
# 47712                60
# 48056               179
# 48431                 0
#
# [48895 rows x 16 columns]

# %%
n_count=df.groupby('neighbourhood_group',as_index=False)['neighbourhood'].value_counts()
# n_df=pd.DataFrame(n_count)
# n_df neighbourhood_group
n_count
# Out:
#     neighbourhood_group   neighbourhood  count
# 0                 Bronx     Kingsbridge     70
# 1                 Bronx         Fordham     63
# 2                 Bronx        Longwood     62
# 3                 Bronx      Mott Haven     60
# 4                 Bronx       Wakefield     50
# ..                  ...             ...    ...
# 216       Staten Island    Richmondtown      1
# 217       Staten Island        New Dorp      1
# 218       Staten Island  Fort Wadsworth      1
# 219       Staten Island     Willowbrook      1
# 220       Staten Island         Woodrow      1
#
# [221 rows x 3 columns]

# %%
sns.scatterplot(data=n_count,x='neighbourhood_group',y='count',hue='neighbourhood')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
df.groupby(['neighbourhood_group'])['neighbourhood'].value_counts()
# Out:
# neighbourhood_group  neighbourhood
# Bronx                Kingsbridge      70
#                      Fordham          63
#                      Longwood         62
#                      Mott Haven       60
#                      Concourse        50
#                                       ..
# Staten Island        New Dorp          1
#                      Richmondtown      1
#                      Rossville         1
#                      Willowbrook       1
#                      Woodrow           1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
sns.swarmplot(data=n_count,x='neighbourhood_group',y='count',hue='neighbourhood')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 72.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 37.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 69.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='neighbourhood_group', ylabel='count'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 77.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 74.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                  40.64749
# longitude                                                -73.97237
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# reviews_per_month                                             0.21
# calculated_host_listings_count                                   6
# availability_365                                               365
#
#                                                     1  \
# id                                               2595
# name                            Skylit Midtown Castle
# host_id                                          2845
# host_name                                    Jennifer
# neighbourhood_group                         Manhattan
# neighbourhood                                 Midtown
# latitude                                     40.75362
# longitude                                   -73.98377
# room_type                             Entire home/apt
# price                                             225
# minimum_nights                                      1
# number_of_reviews                                  45
# last_review                                2019-05-21
# reviews_per_month                                0.38
# calculated_host_listings_count                      2
# availability_365                                  355
#
#                                                                   2  \
# id                                                             3647
# name                            THE VILLAGE OF HARLEM....NEW YORK !
# host_id                                                        4632
# host_name                                                 Elisabeth
# neighbourhood_group                                       Manhattan
# neighbourhood                                                Harlem
# latitude                                                   40.80902
# longitude                                                  -73.9419
# room_type                                              Private room
# price                                                           150
# minimum_nights                                                    3
# number_of_reviews                                                 0
# last_review                                                      NA
# reviews_per_month                                               0.0
# calculated_host_listings_count                                    1
# availability_365                                                365
#
#                                                               3  \
# id                                                         3831
# name                            Cozy Entire Floor of Brownstone
# host_id                                                    4869
# host_name                                           LisaRoxanne
# neighbourhood_group                                    Brooklyn
# neighbourhood                                      Clinton Hill
# latitude                                               40.68514
# longitude                                             -73.95976
# room_type                                       Entire home/apt
# price                                                        89
# minimum_nights                                                1
# number_of_reviews                                           270
# last_review                                          2019-07-05
# reviews_per_month                                          4.64
# calculated_host_listings_count                                1
# availability_365                                            194
#
#                                                                                4
# id                                                                          5022
# name                            Entire Apt: Spacious Studio/Loft by central park
# host_id                                                                     7192
# host_name                                                                  Laura
# neighbourhood_group                                                    Manhattan
# neighbourhood                                                        East Harlem
# latitude                                                                40.79851
# longitude                                                              -73.94399
# room_type                                                        Entire home/apt
# price                                                                         80
# minimum_nights                                                                10
# number_of_reviews                                                              9
# last_review                                                           2018-11-19
# reviews_per_month                                                            0.1
# calculated_host_listings_count                                                 1
# availability_365                                                               0

# %%
df.groupby('host_id').get_group(2787)
# Out:
#              id                                               name  host_id  \
# 0          2539                 Clean & quiet apt home by the park     2787
# 10372   7937553  Riomaggiore Room. Queen Bedroom in Bklyn Townh...     2787
# 13583  10160215                               Torre del Lago Room.     2787
# 13688  10267242  Cinque Terre Room.  Clean and Quiet Queen Bedroom     2787
# 13963  10593675  La Spezia room.  Clean, quiet and comfortable bed     2787
# 21556  17263207   Brooklyn home.  Comfort and clean. Liguria room.     2787
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0          John            Brooklyn    Kensington  40.64749  -73.97237
# 10372      John            Brooklyn   Bensonhurst  40.60951  -73.97622
# 13583      John            Brooklyn     Gravesend  40.60755  -73.97410
# 13688      John            Brooklyn     Gravesend  40.60810  -73.97541
# 13963      John            Brooklyn   Bensonhurst  40.60951  -73.97642
# 21556      John            Brooklyn   Bensonhurst  40.60877  -73.97382
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Private room    149               1                  9  2018-10-19
# 10372  Private room     99               1                 21  2018-10-27
# 13583  Private room     79               1                 17  2019-06-26
# 13688  Private room    149               1                 24  2019-05-11
# 13963   Shared room     79               1                 15  2018-09-29
# 21556  Private room     49               1                 19  2019-06-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                               6               365
# 10372               0.50                               6               153
# 13583               0.40                               6               174
# 13688               0.64                               6               180
# 13963               0.43                               6               180
# 21556               0.70                               6               360

# %%
df['host_id'].value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64

# %%
df.groupby('host_id').value_counts().reset_index()
# Out:
#          host_id        id                                               name  \
# 0           2438  23669201  Great Price: Williamsburg Brooklyn Loft off L ...
# 1           2571   1101224                                         THE PUTNAM
# 2           2787      2539                 Clean & quiet apt home by the park
# 3           2787   7937553  Riomaggiore Room. Queen Bedroom in Bklyn Townh...
# 4           2787  10160215                               Torre del Lago Room.
# ...          ...       ...                                                ...
# 48890  274273284  36478343                              Welcome all as family
# 48891  274298453  36481615                   Peaceful space in Greenpoint, BK
# 48892  274307600  36482783        Brooklyn Oasis in the heart of Williamsburg
# 48893  274311461  36483010                    Comfy 1 Bedroom in Midtown East
# 48894  274321313  36484087  Spacious Room w/ Private Rooftop, Central loca...
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          Tasos            Brooklyn        Williamsburg  40.71412  -73.94447
# 1          Teedo            Brooklyn  Bedford-Stuyvesant  40.68674  -73.93845
# 2           John            Brooklyn          Kensington  40.64749  -73.97237
# 3           John            Brooklyn         Bensonhurst  40.60951  -73.97622
# 4           John            Brooklyn           Gravesend  40.60755  -73.97410
# ...          ...                 ...                 ...       ...        ...
# 48890  Anastasia           Manhattan         East Harlem  40.78749  -73.94749
# 48891     Adrien            Brooklyn          Greenpoint  40.72585  -73.94001
# 48892   Jonathan            Brooklyn        Williamsburg  40.71790  -73.96238
# 48893      Scott           Manhattan             Midtown  40.75561  -73.96723
# 48894        Kat           Manhattan      Hell's Kitchen  40.76392  -73.99183
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt     95              45                  1  2018-03-17
# 1      Entire home/apt    182               9                 27  2019-05-21
# 2         Private room    149               1                  9  2018-10-19
# 3         Private room     99               1                 21  2018-10-27
# 4         Private room     79               1                 17  2019-06-26
# ...                ...    ...             ...                ...         ...
# 48890     Private room    140               1                  0          NA
# 48891     Private room     54               6                  0          NA
# 48892     Private room    190               7                  0          NA
# 48893  Entire home/apt    200               6                  0          NA
# 48894     Private room    125               4                  0          NA
#
#        reviews_per_month  calculated_host_listings_count  availability_365  0
# 0                   0.06                               1                 0  1
# 1                   0.37                               1                23  1
# 2                   0.21                               6               365  1
# 3                   0.50                               6               153  1
# 4                   0.40                               6               174  1
# ...                  ...                             ...               ... ..
# 48890               0.00                               1               180  1
# 48891               0.00                               1                15  1
# 48892               0.00                               1               341  1
# 48893               0.00                               1               176  1
# 48894               0.00                               1                31  1
#
# [48895 rows x 17 columns]

# %%
hosts=df['host_id'].value_counts().reset_index()
hosts
# df_host=pd.DataFrame(hosts,columns=['hostid','count'])
# df_host
# df_hosts=hosts.to_frame()
# df_hosts
# Out:
#            index  host_id
# 0      219517861      327
# 1      107434423      232
# 2       30283594      121
# 3      137358866      103
# 4       16098958       96
# ...          ...      ...
# 37452   23727216        1
# 37453   89211125        1
# 37454   19928013        1
# 37455    1017772        1
# 37456   68119814        1
#
# [37457 rows x 2 columns]

# %%
 # hosts
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64
